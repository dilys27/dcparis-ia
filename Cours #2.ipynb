# %% [markdown]
# # Data Visualisation Statistiques descriptives

# %% [markdown]
# ## EX 1 Visualisation d'un nuage de points et exploration des variables

# %%
#1)

import pandas as pd
import seaborn as sns
import matplotlib as mp
import numpy as np

print("lib loaded")
# Out:
# lib loaded

# %%
#2)

houses = pd.read_csv("./DataSources/house_pricing.csv", sep=",")
print("dataset loaded")
houses.head(10)
# Out:
# dataset loaded
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
houses.dtypes
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#3)

df1 = houses[['LotArea', 'SalePrice']]
df1.plot(x="LotArea",y="SalePrice", kind="scatter")
sns.pairplot(df1)

# %%
#4)

df2 = houses[(houses["LotArea"]<20000) & (houses["SalePrice"]<500000)]
df2.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
#5)

p1 = df2[['LotFrontage', 'LotArea']]
p1.plot(x="LotFrontage",y="LotArea", kind="scatter")
sns.pairplot(p1)

# %%
#6)

df3 = houses[(houses["LotFrontage"]<200) & (houses["LotArea"]<100000)]
df3.head(10)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
p3 = df3[['LotFrontage', 'LotArea']]
p3.plot(x="LotFrontage",y="LotArea", kind="scatter")
sns.pairplot(p3)

# %% [markdown]
# ## EX2 Visualisation de relations continues

# %%
#1)

import matplotlib.pyplot as plt

print("lib loaded")
# Out:
# lib loaded

# %%
dataset = pd.read_csv("./DataSources/sales_predictions.csv", sep=",")

print("dataset loaded")

dataset.head()
# Out:
# dataset loaded
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
#2)

sns.relplot(x='date', y='item_price', ci=None, data=dataset[['item_price', 'date']])

# %% [markdown]
# On peut voir que ce graphe est illisible car on utilise toutes les données de notre fichier (et il en comporte un nombre important).

# %%
#3)

ds = dataset[['item_price', 'date']].sample(50, random_state=1)
sns.relplot(x='date', y='item_price', ci=None, data=ds)

# %% [markdown]
# Pour corriger le problème, il suffit d'utiliser la fonction sample() pour avoir accès à un échantillon des données de notre fichier.

# %%
#4)

f, ax = plt.subplots(figsize=(20,6))
sns.relplot(x='date', y='item_price', ci=None, data=ds, height=6, kind='line', aspect=3)

#fig = plt.figure(figsize=(20,6))
#plt.scatter(ds["date"], ds["item_price"])

# %% [markdown]
# Ce graphe nous permet de mieux visualiser les écarts de valeur entre chaque donnée.

# %%
#5)

ds['date'] = pd.to_datetime(ds['date'])
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 651498 to 31932
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item_price  50 non-null     float64
#  1   date        50 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.2 KB

# %%
#plt.scatter(ds["date"], ds["item_price"])
sns.relplot(x='date', y='item_price', ci=None, data=ds, height=6, kind='line', aspect=3)

# %% [markdown]
# ## EX3 Visualisation de variables catégoriques

# %%
#1)

ibm = pd.read_csv("./DataSources/ibm_hr_attrition.csv", sep=",")

print("dataset loaded")

ibm.head()
# Out:
# dataset loaded
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
#2)

ibm1 = ibm[['Attrition', 'JobSatisfaction']]
sns.catplot(x="Attrition", y="JobSatisfaction", data=ibm1, ci=None, aspect=.6)

# %%
sns.catplot(x="Attrition", y="JobSatisfaction", data=ibm1, kind='box')

# %%
#4)

sns.boxplot(x='Attrition', y='JobSatisfaction', data=ibm1, width=0.3)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='JobSatisfaction'>

# %%
#5)

#Pas de valeurs aberrantes donc on passe la question

# %%
#6)

ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
ibm.info()
ibm.JobSatisfaction.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#7)

#Pas de valeurs aberrantes donc on passe la question.

# %%
#8)

sns.catplot(x="Attrition", y="TotalWorkingYears", data=ibm, kind='box')

# %%
sns.catplot(x="Attrition", y="TotalWorkingYears", data=ibm.query("TotalWorkingYears<20"), kind='box')

# %%
#9)

#ibm['Attrition'] = np.where(ibm['Attrition'] == "No", 0, 1)
ibm['Attrition'] = ibm['Attrition'].replace(to_replace=["Yes", "No"], value=[1,0])

# %%
#10)

#ibm2 = ibm[['Attrition', 'EducationField']]
#ibm2.hist(column='Attrition', by='EducationField')

sns.catplot(x="Attrition", y="EducationField", data=ibm, kind='bar')

# %% [markdown]
# ## EX4 Visualisation d'une distribution

# %%
#1)

ibm.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#2)

mon = ibm['MonthlyIncome']
sns.distplot(mon)
plt.grid(True)
plt.show()

# %%
#3)

mon = mon[(mon>0) & (mon<5000)]
sns.distplot(mon)
plt.grid(True)
plt.show()

# %% [markdown]
# ## EX 5 Visualisation d'une relation linéaire

# %%
#1)

ibm.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#2)

proba = ibm[['Attrition','DistanceFromHome', 'YearsWithCurrManager']]
proba.head()
# Out:
#    Attrition  DistanceFromHome  YearsWithCurrManager
# 0          1                 1                     5
# 1          0                 8                     7
# 2          1                 2                     0
# 3          0                 3                     0
# 4          0                 2                     2

# %%
sns.lmplot(x="DistanceFromHome", y="Attrition", data=proba);
plt.grid(True)
plt.show()

# %%
#3)

sns.lmplot(x="YearsWithCurrManager", y="Attrition", data=proba);
plt.grid(True)
plt.show()

# %% [markdown]
# ## EX6 Visualisation d'une heatmap

# %%
#1

houses.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#2)

#data=houses[houses.columns[:15]]
data = houses.iloc[:, 64:81]
data.head()
# Out:
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# ...

# %%
#3)

data.corr()
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %%
#4)

sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#5)

#Top 3 Features : WoodDeckSF / OpenPorchSF / ScreenPorch
